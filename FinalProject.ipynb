# %% [markdown]
# # CECS 456 Final Project - Fire Prediciton

# %% [markdown]
# ## Data Preprocessing

# %%
import pandas as pd
import numpy

# %% [markdown]
# ## Model Design And Training

# %% [markdown]
# ## Model Improvements

# %% [markdown]
# ### Hyperparamter Tuning

# %% [markdown]
# ### Feature Selection

# %% [markdown]
# ### Model Fusion

# %% [markdown]
# ### Regularization Techniques

# %% [markdown]
# ## Model Comparison and Interpretation
